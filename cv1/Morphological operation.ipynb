# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('img1.jpg')
plt.imshow(img)

# %%
#Erosion
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('img1.jpg',0)

#binarize the image
binr=cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

#difine the kernel
kernel=np.ones((5,5),np.uint8)

#invert the image
invert=cv2.bitwise_

# %%
#dilation
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('img1.jpg',0)

#binarize the image
binr=cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

#difine the kernel
kernel=np.ones((3,3),np.uint8)

dilation=cv2.dilate(invert,kernl)

# %%
#opening
import cv2

import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread('img1.jpg',0)

#binarize the image
binr=cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

#difine the kernel
kernel=np.ones((3,3), np.uint8)

#opening the image
opening=cv2.morphologyEx(binr,cv2.MORPH_OPEN, kernel,itererat)

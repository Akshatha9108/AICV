# %%
import cv2

img=cv2.imread('tiger.jpeg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blurred=cv2.GaussianBlur(gray,(3,3), 0)

edged=cv2.Canny(blurred,10,100)

cv2.imshow("Original",img)
cv2.imshow("Edged img",edged)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# ...

# %%
import cv2

img=cv2.imread('tiger.jpeg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blurred=cv2.GaussianBlur(gray,(3,3), 0)

threshold_wide=cv2.Canny(blurred,30,250)

cv2.imshow("Original",img)
cv2.imshow("threshold_wide",threshold_wide)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# ...

# %%
contours,_=cv2.findContours(edged,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
img_copy=img.copy()
#draaw the contours on a copy of the original image
cv2.drawContours(img_copy,contours,-1,(0,255,0),2)
print(len(contours),"objects were found in this image.")

cv2.imshow("Edged image",edged)
cv2.imshow("Contours",img_copy)
cv2.waitKey(0)
# Out:
# 223 objects were found in this image.
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# QObject::moveToThread: Current thread (0x55858f52acf0) is not the object's thread (0x55858fa6b120).
# Cannot move to target thread (0x55858f52acf0)
#
# ...
